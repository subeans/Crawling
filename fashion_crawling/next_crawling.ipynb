# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import urllib.request as ur
import random
import time
import json

# %%
def getFeature(good_list,bad_list,a_list):
    count=0
    pagenum=1
    options=webdriver.ChromeOptions()
    driver=webdriver.Chrome('./chromedriver')
    driver.implicitly_wait(1)
    #woman_shorts
    driver.get('https://www.amazon.com/s?i=fashion-womens-intl-ship&bbn=16225018011&rh=n%3A16225018011%2Cn%3A1040660%2Cn%3A1048186&dc&pf_rd_i=16225018011&pf_rd_m=ATVPDKIKX0DER&pf_rd_p=0909843d-7d3a-40a7-8b35-6c3da8755bbd&pf_rd_p=0909843d-7d3a-40a7-8b35-6c3da8755bbd&pf_rd_r=W0B8SC0KBX7PVH85GSQQ&pf_rd_r=W0B8SC0KBX7PVH85GSQQ&pf_rd_s=merchandised-search-left-2&pf_rd_t=101&qid=1562351746&rnid=1040660&ref=sr_nr_n_8')
    html=driver.page_source
    soup=BeautifulSoup(html,'html.parser')
    
    while True:
        #h=0
        #id_list=[]
        products=soup.findAll('a',attrs={'class':'a-link-normal a-text-normal'})
        if(len(products)==0):
            driver.refresh()
        else:
            print(len(products))
            gender='woman'
            info={}
            cnt=1
        
        #ids=soup.findAll('div',attrs={'class':'sg-col-4-of-24 sg-col-4-of-12 sg-col-4-of-36 sg-col-4-of-28 sg-col-4-of-16 sg-col sg-col-4-of-20 sg-col-4-of-32'})
        #for j in range(48):
          #  id=ids[j].get('data-asin')
           # id_list.append(id)
        #driver.implicitly_wait(7)
    
            minus=len(products)-48
            print(minus)
            if(minus>0):
                for j in range(len(products)):
                    product=products[j].get('href')
                    if(j>=minus):   
                        try:
                            url="https://www.amazon.com"+product
                    #except:
                      #  a_list.append(product)
                            time.sleep(1)
                            driver.get(url)
                            html=driver.page_source
                            soup=BeautifulSoup(html,'html.parser')
                            time.sleep(1)
                            title=soup.select('#productTitle')[0].text.strip()
                            try:
                #id=soup.select('#multipleRecommendations')[0].get('data-asin')
                                id=soup.select('#cerberus-data-metrics')[0].get('data-asin')
                            except:
                                id='none'
                            category_select = soup.select('#wayfinding-breadcrumbs_feature_div > ul > li > span')
                            category = []
                            for single_category in category_select:
                                category.append(single_category.text.strip())
    
                            feature_select = soup.select('#feature-bullets > ul > li > span')
                            feature = []
                            for single_feature in feature_select:
                                feature.append(single_feature.text.strip())
                            imgurl_select = soup.select('#landingImage')[0]['data-a-dynamic-image']
                            imgurl = (imgurl_select.split('\"')[1])
                            h+=1
                            if (id=='none'):
                                info = {
                                'id' : str(pagenum)+'-'+str(cnt),
                                'title' : title,
                            'category' : category,
                            'features' : feature,
                            'gender' : gender,
                            'img_links' : imgurl
                        }
                                bad_list.append(info)
                                count+=1
                            else:    
                                info = {
                        'id' : id,
                        'title' : title,
                        'category' : category,
                        'features' : feature,
                        'gender' : gender,
                        'img_links' : imgurl
                        }
                                good_list.append(info)
                                count+=1
                            cnt+=1
                            print(str(count)+'th')
                            print(info)
                #if (len(good_list)%1000==0):
                   # json.dump(good_list,open('./newCrawling_womanShorts'+len(good_list)+'.json','w+'))
            
                            driver.back()
                        except:
                            if (j==47):
                                a_list.append(product)
                                a_last=driver.find_elements_by_class_name('a-last')[0]
                                a_last.click()
                            else:
                                a_list.append(product)
                    
                a_last=driver.find_elements_by_class_name('a-last')[0]
                a_last.click()
                pagenum+=1
                html=driver.page_source
                soup=BeautifulSoup(html,'html.parser')
                time.sleep(1)
        
            else:     
                for h in range(len(products)):
                    if (h>=2):
                        driver.get(url)
                        html=driver.page_source
                        soup=BeautifulSoup(html,'html.parser')
                        time.sleep(1)
                        title=soup.select('#productTitle')[0].text.strip()
                        try:
                    #id=soup.select('#multipleRecommendations')[0].get('data-asin')
                            id=soup.select('#cerberus-data-metrics')[0].get('data-asin')
                        except:
                            id='none'
                        category_select = soup.select('#wayfinding-breadcrumbs_feature_div > ul > li > span')
                        category = []
                        for single_category in category_select:
                            category.append(single_category.text.strip())
                        
                        feature_select = soup.select('#feature-bullets > ul > li > span')
                        feature = []
                        for single_feature in feature_select:
                            feature.append(single_feature.text.strip())
                        imgurl_select = soup.select('#landingImage')[0]['data-a-dynamic-image']
                        imgurl = (imgurl_select.split('\"')[1])
                        h+=1
                        if (id=='none'):
                            info = {
                            'id' : str(pagenum)+'-'+str(cnt),
                        'title' : title,
                        'category' : category,
                        'features' : feature,
                        'gender' : gender,
                        'img_links' : imgurl
                    }
                            bad_list.append(info)
                            count+=1
                        else:    
                            info = {
                            'id' : id,
                            'title' : title,
                            'category' : category,
                            'features' : feature,
                            'gender' : gender,
                            'img_links' : imgurl
                            }
                            good_list.append(info)
                            count+=1
                        cnt+=1
                        print(str(count)+'th')
                        print(info)
                    if (len(good_list)%1000==0):
                        json.dump(good_list,open('./newCrawling_womanShorts'+len(good_list)+'.json','w+'))
            
                        driver.back()
                break

# %%
good_list=[]
bad_list=[]
a_list=[]
getFeature(good_list,bad_list,a_list)

json.dump(good_list,open('./new_Crawling_womanShorts.json','w+'))
json.dump(bad_list,open('./no_id_womanShorts.json','w+'))
json.dump(a_list,open('./banList_womanShorts.json','w+'))
# Out:
# 50
# 2
# 1th
# {'id': 'B07CKSHLC5', 'title': 'ODODOS High Waist Out Pocket Yoga Short Tummy Control Workout Running Athletic Non See-Through Yoga Shorts', 'category': ['Sports & Outdoors', '›', 'Sports & Fitness', '›', 'Exercise & Fitness', '›', 'Yoga', '›', 'Clothing', '›', 'Women'], 'features': ['86%Polyester/14%Spandex,86%Nylon/14%Spandex', 'Imported', "Choose between solid, Heather,SpaceDye You decide what's best for you. You're covered by our 100% full money-back guarantee.", 'If you don\'t love our products, simply return them without question within 30 days. Select your favorite color and ""Add to Cart"" now.', 'Using 4 way Stretch & Non See-through Fabric. Perfect for yoga, exercise, fitness, any type of workout, or everyday use. ODODOS High Waist Out Pocket Yoga Shorts combine fashion, function and performance.', 'These ODODOS High Waist Out Pocket Yoga Shorts for women are made from the highest quality fabrics designed to remove moisture from your body, providing maximum comfort.', 'Fabric is designed to contour perfectly to your body, giving you a streamlined look.'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/61-GXwAGV%2BL._UX466_.jpg'}
# 2th
# {'id': 'B0775B4K9Y', 'title': 'Amazon Essentials Women\'s 5" Inseam Chino Short', 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Casual'], 'features': ['100% Cotton', 'Imported', 'Machine Wash', '0.7" high', '14" wide', 'This chino short features a classic fit and mid-length inseam for a versatile, casual look', 'Zip fly with button closure, off-seam side pockets, decorative rear welt pockets'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/816QF0soh-L._UX466_.jpg'}
# 3th
# {'id': 'B07755HFPF', 'title': 'Amazon Essentials Women\'s 10" Inseam Bermuda Short', 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Casual'], 'features': ['98% Cotton, 2% Spandex', 'Imported', 'Machine Wash', 'Bring a classic casual vibe to your ensemble with this essential bermuda short featuring a slightly tapered leg', 'Zip fly with button closure, off-seam side pockets, decorative rear welt pockets', 'Inseam measures 10"', 'Also available in 3.5", 5", and 7" inseams', 'Everyday made better: we listen to customer feedback and fine-tune every detail to ensure quality, fit, and comfort'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/71ff8VeOUDL._UY879_.jpg'}
# 4th
# {'id': 'B07CNCQFG4', 'title': "luvamia Women's Mid Rise Shorts Frayed Raw Hem Ripped Denim Jean Shorts", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Denim'], 'features': ['To guarantee the quality, Please make sure your order placed from "LUVAMIA"!!!!', 'DO NOT SIZE UP! Material is stretchy. Size Small fits US 4-6, Medium fits US 8-10, Large fits US 12-14, X-Large fits US 16-18, XX-Large fits US 20-22.', 'Casual summer hot pants features mid waist, frayed detailing and raw hemline. Slightly side slit.', 'Zipper fly, 5 functional pockets, button closure. Slim fit, fashion and cute. Stretchy. Machine washable.', 'Ripped denim shorts for women and juniors. Perfect for summer daily wear, going out, night out, dating, etc'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/81VC8XZ64yL._UY500_.jpg'}
# 5th
# {'id': 'B00QKEFA6E', 'title': "Soffe Juniors' Authentic Short", 'category': ['Sports & Outdoors', '›', 'Outdoor Recreation', '›', 'Outdoor Clothing', '›', 'Women', '›', 'Shorts'], 'features': ['50% Polyester/50% Cotton', 'Imported', 'Machine Wash', 'Casual short featuring exposed elastic waistband and side slits at legs', 'Note: The short is typically worn – with the waistband rolled down, therefore highlighting the white waistband. Should the wearer choose to wear the shorts without rolling the waistband down – the garment is all black.'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/81nFFrTyOKL._UY500_.jpg'}
# 6th
# {'id': 'B01K8V7PDK', 'title': 'Hybrid Womens Hyper Ultra Stretch Comfy Skinny Pants, Capri, Bermuda', 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Pants'], 'features': ['PREMIUM ULTRA STRETCH FABRIC: 75% Cotton | 20% Polyester | 5% SPANDEX (Fabric blended with spandex for stretch and comfort.)', "STRETCHY VERSATILE PANTS: Wiggle into these super-stretch skinny pants and you'll be ready to conquer the world in comfort. They're perfect for pairing with a blouse and leather jacket, and easy enough to wear for weekend lounging.", 'STYLE & FUNCTION: Mid-rise, Flattering skinny fit with functional front and back pockets, Zip-fly closure.', 'ALL DAY COMFORT: Most comfortable Stretchy waist, providing all around ease & roominess, never too tight or restrictive. Perfect from office to happy hour.', 'EASY CARE: Machine Washable', 'GREAT SELECTIONS: Available in full pants, capri and Bermuda, White Color has blue undertone, and off-white have yellow undertone'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/611DzG1Ij1L._UY445_.jpg'}
# 7th
# {'id': 'B073J8466S', 'title': 'OLRAIN Womens High Waist Ripped Hole Washed Distressed Short Jeans', 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Denim'], 'features': ['85%Cotton+10%Polyester+5%Elastane, comfortable and stretchy', 'High waited destroyed denim shorts with a cuffed hem fit for a curvier look. Zip closure in the material for a comfortable fit.', 'It is casual and fashionable to wear the Mid -rise distressed denim shorts, pairs well with any fitted or flowy top or together with Tops, Tank, Casual T-shirts, Vest, Blouses etc', 'This ripped short jeans combines the look of your favorite pair of jeans with just the right amount of stretch . With their good looks and luxurious construction, it is perfect for your leisure time activities.', "Hand wash or machine wash, and it is A little faded, don't mix with other clothes."], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/71l8OtiQO-L._UY879_.jpg'}
# 8th
# {'id': 'B06X92NBKS', 'title': 'Conceited Premium Ultra Soft Harem Shorts - Pockets - 40 Trending Prints', 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Casual'], 'features': ['PREMIUM STRETCH MATERIALS - 92% Polyester, 8% Spandex', 'TRENDING - These super soft comfortable harem-style shorts are trending this season. Wear them out at night or casually around town. Only you will know how soft and comfortable they are!', 'STYLE - These shorts have side pockets and a banded waist and come in solid colors as well as this season’s most trending prints.', 'PERFECT FIT - Choose between Small/Medium (0-10) and Medium/Large (12-18), for a perfect fit. Don’t settle for one size fits all.', "FREE RETURNS - Buy risk-free: We’re confident you’ll love our products, but you can return this item for any reason and get a full refund, we'll even pay your return shipping!", 'LIMITED PRINTS - Our prints are limited - Order now to avoid missing out on your favorite prints'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/61toCgLXu8L._UY679_.jpg'}
# 9th
# {'id': 'B07JM6YZH1', 'title': 'Amazon Essentials Women\'s 7" Inseam Chino Short', 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts'], 'features': ['100% Cotton', 'Imported', 'Machine Wash', 'This chino short features a classic fit and mid-length inseam for a versatile, casual look', 'Zip fly with button closure, off-seam side pockets, decorative rear welt pockets', 'Inseam measures 7"', 'Also available in 3.5", 5", and 10" bermuda inseams', 'Everyday made better: we listen to customer feedback and fine-tune every detail to ensure quality, fit, and comfort'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/71tKB%2Bk-zqL._UX522_.jpg'}
# 10th
# {'id': 'B077555TJJ', 'title': 'Amazon Essentials Women\'s 5" Drawstring Linen Short', 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts'], 'features': ['100% Linen', 'Imported', 'Machine Wash', 'Lightweight linen construction makes these shorts a must-have pick for laid-back looks', 'Side and rear pockets, elastic waistband with drawstring', 'Everyday made better: we listen to customer feedback and fine-tune every detail to ensure quality, fit, and comfort'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/71Adp3%2BY9CL._UY550_.jpg'}
# 11th
# {'id': 'B07JLBBD3Y', 'title': 'Amazon Essentials Women\'s 3.5" Inseam Chino Short', 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts'], 'features': ['100% Cotton', 'Imported', 'Machine Wash', 'This chino short features a classic fit and mid-length inseam for a versatile, casual look', 'Zip fly with button closure, off-seam side pockets, decorative rear welt pockets', 'Inseam measures 3.5"', 'Everyday made better: we listen to customer feedback and fine-tune every detail to ensure quality, fit, and comfort'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/71JF-ExvIrL._UX522_.jpg'}
# 12th
# {'id': 'B07J3DWMRT', 'title': 'Amazon Essentials Women\'s 5" Denim Short', 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Denim'], 'features': ['82% Cotton, 17% Polyester, 1% Elastane', 'Imported', 'Machine Wash', 'Bring a classic casual vibe to your ensemble with this essential denim short', 'Inseam of 5"', 'Everyday made better: we listen to customer feedback and fine-tune every detail to ensure quality, fit, and comfort'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/81flTJuA4qL._UY550_.jpg'}
# 13th
# {'id': 'B071GR5D6F', 'title': "PHOENISING Women's Sexy Stretchy Fabric Hot Pants Distressed Denim Shorts,Size 2-16", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Denim'], 'features': ['Frayed Fabric Short Shorts,2 Front Buttons,Light Weight,Soft & Comfy', 'Zip Fly & Button Closure,Designed Hot Pants for Girls & Ladies At All Ages', 'Distressed Jean Shorts,Hot Pants,Raw Edge,Skinny & Stretchy', 'Very Slim Fit Shorts,Cute & Cool Bottom Wear for Everyday Life in Summer', 'Everyday Denim for Summer.Choose One Size Up If You A Little Plump'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/71cattwWlxL._UX342_.jpg'}
# 14th
# {'id': 'B07J3F6W3F', 'title': 'Amazon Essentials Women\'s 10" Denim Bermuda Short', 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Denim'], 'features': ['82% Cotton, 17% Polyester, 1% Elastane', 'Imported', 'Machine Wash', 'Bring a classic casual vibe to your ensemble with this essential bermuda short featuring a slightly tapered leg', 'Zip fly with button closure, off-seam side pockets, decorative rear welt pockets', 'Everyday made better: we listen to customer feedback and fine-tune every detail to ensure quality, fit, and comfort'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/81jM5tz2yxL._UY879_.jpg'}
# 15th
# {'id': 'B0797PW6Q8', 'title': "SweatyRocks Women's Casual Elastic Waist Striped Summer Beach Shorts with Pockets", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Casual'], 'features': ['Material: Cotton and Polyester', 'Frill Waist, Plain/Striped Pattern, Elastic Waist, Self-tied Belt, Two side pockets', 'Loose fit, Casual, Cute and Elegant, Suit for summer days. Suitable for beach or pool,work,vacation and daily wear', 'Comfy and light fabric, stretchy waistline makes the shorts even more comfortable.', 'Please refer to the size measurement in the image before ordering'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/81PrkUvQCoL._UY606_.jpg'}
# 16th
# {'id': 'B07FDZHS83', 'title': "Amazon Essentials Women's French Terry Fleece Short", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts'], 'features': ['60% Cotton, 40% Polyester', 'Imported', 'Machine Wash', 'Super soft French terry will make these shorts a go-to for lounging, errands or hitting the gym', 'Features pockets and an elasticized waistband with adjustable drawstring', 'Everyday made better: we listen to customer feedback and fine-tune every detail to ensure quality, fit, and comfort'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/719xR6RgsHL._UY500_.jpg'}
# 17th
# {'id': 'B00Q459EZM', 'title': "LEE Women's Relaxed-Fit Bermuda Short", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Casual'], 'features': ['82% Cotton/17% Polyester/1% Spandex', 'Imported', 'Machine Wash', 'COVER THE BASICS: A classic from the moment we designed it, this relaxed-fit, versatile bermuda short has you covered, & that leaves you free to cover the rest of your life with class. Movement and style, all day long. What a wonderful habit to get into', "STYLISH DESIGNS: Lee's full line of women's shorts, women's jeans, women's skirts, women's jackets & more provide you with a stylish wardrobe all year round. From denim skirts for summer barbecues to jean jackets for windy fall days, Lee keeps you going", "MORE THAN DENIM: You already trust Lee to bring you your favorite jeans, but we're so much more than that! Lee makes quality, stylish jeans, khakis, dresses, skirts, jackets, belts, shorts, shirts, uniforms and more! Fill your closet with Lee quality", "QUALITY OVER QUANTITY: For over 100 years, Lee has been making quality, dependable denim. We'd rather sell one quality garment than 100 inferior ones. If you're looking for quality jeans, shorts, jackets, skirts, overalls, belts or uniforms, look to Lee"], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/81cN8Vc3DTL._UX522_.jpg'}
# 18th
# {'id': 'B0166BU7T0', 'title': '90 Degree By Reflex Soft and Comfy Activewear Lounge Shorts with Pockets and Drawstring for Women', 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Casual'], 'features': ['The Soft and Comfy Activewear Lounge Shorts with Pockets for Women by 90 Degree by Reflex are perfect for active women who want comfort and flexibility. Our fabric is made of a specialized polyester/spandex blend that moves with you. The fabric is breathable and also has moisture-wicking technology that keeps you dry. You can go through your most vigorous workout with complete comfort.', 'These womens shorts have four way stretch which is ideal for free movement and elasticity. In addition, these yoga shorts have interlocked seams to minimize rubbing and chafing. Also, these womens running shorts have a drawstring to perfectly adjust to your body. Style these womens shorts with our 90 Degree by Reflex Power Flex Open Back Mesh Tank Top for an effortlessly fashionable look!', '90 Degree by Reflex is a lifestyle brand that prides itself on offering active wear that is high quality but also affordable. We believe your workout clothes should keep up with you during any exercise or activity. From the gym to the street, and lounging in between, Reflex allows you to Relax, Reflect, Rebound.', 'We currently offer these athletic shorts in Heather Grey, Heather Charcoal and Heather Navy in sizes X-Small, Small, Medium, Large and X-Large. These comfy women’s active shorts are comprised of 96% Polyester and 4% Spandex. Cool wash your yoga shorts with like colors and lay flat to dry.', 'While we’re confident you’ll fall in love with our 90 Degree by Reflex Soft and Comfy Activewear Lounge Shorts with Pockets, they are sold with a 30-day, full-money-back warranty and can be returned no questions asked. Add these workout shorts to your cart by clicking the "Add-to-Cart" button and buy it now. We run out of inventory quickly, so order your womens gym shorts now while colors and styles last!'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/81LRTpd4XIL._UX679_.jpg'}
# 19th
# {'id': 'B07C9W6183', 'title': "Cityoung Women's Casual Pleated Tennis Golf Skirt with Underneath Shorts Running Skorts", 'category': ['Sports & Outdoors', '›', 'Sports & Fitness', '›', 'Golf', '›', 'Clothing', '›', 'Women', '›', 'Skirts & Skorts'], 'features': ['90% polyester 10% spandex', 'Imported', 'TWO LAYER, shorts inner and skirt outer. Moves without worries.', 'One pocket on the back.', 'WIDE WAISTBAND with inner drawcord, flat and elastic, adjustable and comfortable to wear, fits body well.', 'Soft, Lightweight and Stretchy. Comfortable for all seasons and various occasions.', 'ATTENTION: In order to improving the function of our skirts, we add an upside down pocket on shorts to carrying tennis balls.'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/81aKmeuDFzL._UX342_.jpg'}
# 20th
# {'id': 'B01GFA115Q', 'title': "Wax Women's Juniors Stetchy Mid Rise Denim Shorts", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Denim'], 'features': ['75% Cotton/23% Polyester/2% Spandex', 'Imported', 'Mid rise denim shorts with triple mini buttons and zip fly closure in front. Cuffed along the bottom edges with traditional 5 pockets. Descent stretch in the material for a comfortable fit.', 'Machine Wash Cold', 'Light Denim, Denim, Medium Denim: 75% Cotton/23% Polyester/2% Spandex // Black, White & Super Dark: 75% Cotton 23% Polyester 2% Spandex', 'Light Denim, Denim, Medium Denim: 10"/25.5 cm Top to Bottom 2.5"/6.5 cm Inseam (Size Medium) Model is 5\'5 and Wearing a Size Small &// Black, White & Super Dark: 10"/25.5 cm Top to Bottom 2.5"/6.5 cm Inseam - Measured on a size Small (Model is 5\'7/ Wearing a Size S)', 'Size Info: Small - 1, 3 / Medium - 5, 7 / Large - 9, 11'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/71frfxxzkdL._UY741_.jpg'}
# 21th
# {'id': 'B00AZBM1YW', 'title': "Columbia Women's Coral Point Ii Short", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Casual'], 'features': ['100% Nylon', 'Made in USA or Imported', "ADVANCED TECHNOLOGY: Columbia Women's Coral Point II Short features our signature wicking fabric that pulls moisture away from the body as well as UPF 30 sun protection that helps block UVA and UVB rays.", 'HANDY FEATURES: Two side pockets and a single back pocket keep your smaller items secure.', 'CLASSIC FIT: These lightweight shorts provide a classic fit for casual days outside.', 'FABRIC: These shorts are crafted of a 100% nylon material for a soft-to-the-touch, lightweight feel.', 'OMNI-SHADE: Be safe and protected. Omni-Shade blocks UVA and UVB rays to help prevent sunburns and long-term skin damage. The tight weave construction with UV absorbent yarns block the full spectrum of harmful UV rays.'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/71zIdhYWrUL._UY500_.jpg'}
# 22th
# {'id': 'B07J4VR57C', 'title': 'HyBrid & Company Womens 7 inch Inseam Super Comfy Bermuda Walking Shorts', 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts'], 'features': ['FABRIC: 98% Algodon Cotton | 2% Spandex', "FASHIONABLE COMFORT: You don't have to be in Bermuda to feel beach-ready in these sophisticated shorts. Breathable cotton is finished with the comfort of spandex, making them super comfortable and perfect for pairing with a pair of wedges and a flowy blouse.", 'GREAT FOR ALL OCCASION: Perfect match for button-downs or tees. Great short to wear on a warm day.', 'LIGHTWEIGHT: This walking Shorts are made from lightweight cotton and washed for softness and durability', 'FEATURE: This short feature a Zip fly and button closure with Belt loops so you can accessorized this short with a cute belt.', 'EASY CARE: Simply toss this pant into the washing machine and dryer for easy hassel free cleaning.'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/71g8mvu0wFL._UY679_.jpg'}
# 23th
# {'id': 'B07R3QRVMZ', 'title': 'Freeprance Paper Bag Shorts for Women high Waisted Casual Shorts Elastic Waist Front Pockets', 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Casual'], 'features': ['2019 New Arrivals - 30% off Paper bag shorts', 'Slim Fit Design – Freeprance’s paper bag shorts of high waist accentuate your leg length and make you look taller and slimmer. The casual shorts length is hit right at the thigh , to create a super flattering silhouette. Women summer shorts for work also have deep patch pockets for your phone and keys', 'Great Fabric & Comfy - Freeprance’s casual shorts for women are made from 95%Polyester+5%Spandex. Comfy fit, elastic waist makes it is easy to pull on, two side pockets design, loose fit style with high waist. Size information in different brand is different. So please must measurement your Size, and refer to Our Size Chart. Thanks for your support.', 'Elastic Waist with Belt - Playful pleated details on a cinched waist tie paper bag short trouser creates a sophisticated and ultra-stylish ensemble. You will love this stretch waist and plus the self-tie belt details. Makes it is easy to pull on. Definite wardrobe must-have, versatile high waist shorts can be worn with multiple looks, keeping you stylish all day long.', 'Perfect Option for All Occasions - Paper bag shorts with belt that you need in your life! Casual shorts for women feature a cropped length and adjustable waist. These self-belted shorts are the perfect option for a day at work followed by an evening out! Women’s shorts suitable for work, office, date, school, gathering, vacation, holiday, outdoors, casual out, daily wear, etc.', "All Match & Flattering - Shorts fit like a dream, are super comfortable and fashion. High waisted paper bag shorts for women are a summer must have! You'll love the cut of this style, which is easy match. These shorts make for a perfect fit every time! Amazing with a simple white cami, and favorite low block sandals, Sergio Rossi or heeled for the perfect attire."], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/51kc2PiXyxL._UX679_.jpg'}
# 24th
# {'id': 'B07K95KMGK', 'title': "LEE Women's Flex-to-go Relaxed Fit Cargo Short", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Casual'], 'features': ['98% Cotton, 2% Spandex', 'Imported', 'Zipper closure', 'Machine Wash', 'Mid rise, relaxed fit, cargo short', 'Featuring a flex-comfort waistband', 'Total of 6 pockets'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/71DoTdCG8QL._UX466_.jpg'}
# 25th
# {'id': 'B07CQNKPYY', 'title': 'Sidefeel Women Casual Frayed Destroy Bermuda Denim Ripped Short Jeans', 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Denim'], 'features': ['Front distressing and raw hemline cut at short length with frayed detailing', 'Front button and zipper closure with 5 pockets', 'Style with a crop top and booties for casual street fashion', 'Must have denim Bermuda shorts with a high rise fit', 'Zip fly bronze button closure, cut at knee length'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/71UtCH1eFKL._UY550_.jpg'}
# 26th
# {'id': 'B01MZGVHYF', 'title': "Wax Women's Juniors Mid-Rise Denim Shorts", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Denim'], 'features': ['High Quality: 75% Cotton, 23% Polyester, 2% Spandex', 'The perfect fit mid rise denim shorts for any wardrobe. Traditional 5 pockets with button and zip fly closure. Great stretch in the material for a comfortable fit. Pairs well with any fitted or flowy top.', 'Machine Wash Cold', '75% Cotton/23% Polyester/2% Spandex', '10.5"/27 cm Top to Bottom, 2.5"/6.5 cm Inseam (Model is 5\'5 and Wearing a Size Small)', 'Designed in Los Angeles, California'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/51qw8FPz24L._UY445_.jpg'}
# 27th
# {'id': 'B01E61CD1C', 'title': "Rekucci Women's Ease Into Comfort Stretchable Pull-On 5 inch Slimming Tab Short", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Casual'], 'features': ['Made in Cambodia or China. Machine Wash in cold water, always hang to dry to avoid shrinkage.', 'COMFORTABLY CHIC: Wide smoothing contour waistband with hidden elastic. Pull-On styling. Look chic, be confident and comfortable', 'PURE FLATTERY: Inseam 5"/ Leg opening 11" - flattering length and wider leg opening - perfectly lengthens and visually slims your legs. Model is 5\'9" and wearing size 6', 'ELEVATED STYLING: Real pockets on front and back. Snap details at the waist and on side tabs. This short will let you love the way you look and become your new summer go-to item', 'STRETCH WOVEN FABRIC: Solid Colors: Rayon/Nylon/Spandex blen, Melange Colors: Polyester/Rayon/Nylon/Spandex blend. Contents on colors, prints, textures may vary.'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/61l5gbXMc9L._UY445_.jpg'}
# 28th
# {'id': 'B071CV6M4Z', 'title': "SweatyRocks Women's Dolphin Running Workout Shorts Yoga Sport Fitness Short Pant", 'category': ['Sports & Outdoors', '›', 'Sports & Fitness', '›', 'Exercise & Fitness', '›', 'Yoga', '›', 'Clothing', '›', 'Women', '›', 'Shorts'], 'features': ['Material: Cotton Blends', 'Colorblock Contrast Trim, Elastic Waist, Drawstring, Mid Waist', "Stretchy, soft, and very comfortable, well-fitting, good for running errands, jogging, gym workout, yoga or lounge wear/night's sleep", 'Casual and sporty style, loose fit, lightweight; great for summer', 'If you want it more loose, you can choose one size up for better comfort'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/711y0Ol2jRL._UX466_.jpg'}
# 29th
# {'id': 'B0131JMM0W', 'title': "Chic Classic Collection Women's Easy-Fit Elastic Waist Pull-On Capri Pant", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Pants', '›', 'Casual'], 'features': ['Dark Shade, Black Stretch: 80% Cotton, 19% Polyester, 1% Spandex; Mid Shade: 79% Cotton, 20% Cotton, 1% Spandex', 'Imported', 'Machine Wash', 'Capri pant in stretch fabrication featuring pull-on flat elastic waistband with faux fly', 'Slash front pocket', 'Inseam: 19"'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/91r83qjSQ2L._UX522_.jpg'}
# 30th
# {'id': 'B07CBDBPZ2', 'title': "Plaid&Plain Women's High Waisted Denim Shorts Rolled Blue Jean Shorts", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Denim'], 'features': ['100% Cotton', 'Imported', 'Zipper & Button closure', 'With a woven belt', 'Elastic waist make them comfy denim shorts for women', 'High waisted jean shorts with a cuffed hem and a “A-line” fit for a cute & flattering looking', 'You can wear these high waisted shorts with t-shirts, crop tops, sweater, sweatshirts in different seasons', 'Loose fit jean shorts for women with decently thick fabric, not only for summer, but also a good choice (with leggings inside) for spring & autumn'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/61QtABVgn8L._UX679_.jpg'}
# 31th
# {'id': 'B01DYHXCXW', 'title': "roswear Women's Ripped Denim Destroyed Mid Rise Stretchy Bermuda Shorts Jeans", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Denim'], 'features': ['85%Cotton/10%Polyester/5%Elastane', 'Zipper closure', 'Timeless fashion and popular destroyed style world widely.', 'Relaxed Mid-rise Fit with Belt Loops and Four Pocket Styling. Belt loops.', 'Good stretchy fabric. Perfect for your leisure time activities.', 'Fabric blended with spandex for stretch and comfort', 'Hand wash or machine wash in pocket.'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/61C7703eHWL._UY879_.jpg'}
# 32th
# {'id': 'B07QNRPLQY', 'title': 'Shapermint: Empetua All Day Every Day High-Waisted Shaper Shorts - Body Shaper', 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Lingerie, Sleep & Lounge', '›', 'Lingerie', '›', 'Shapewear', '›', 'Control Panties'], 'features': ['360° COVERAGE: You read that right! The Empetua High-Waisted Shaper Shorts provide coverage where you need it - tummy, waist, and back.', 'ULTRA COMFORTABLE CONTROL: Who wants compression you can’t breathe in? We’ve tried and tested every feature to make sure you get the ultimate coverage with supreme comfort.', 'ANTI-SLIP TECHNOLOGY: No more bunching, pinching or getting squeezed in the wrong places. The anti-slip silicone strip helps this shapewear stay in place and lets you live your life!', 'NO PANTY LINES: Say farewell to panty lines! Empetua was created by women with all body types to help give you comfortable shapewear that feels great and boosts your confidence.', "FREE EXCHANGES: We cater to all body types. If you don't love the fit, it's most likely a sizing issue - let us know and we'll send you a new size, for free!"], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/61A6ddR8i-L._UY679_.jpg'}
# 33th
# {'id': 'B07BR17VMT', 'title': "Wax Women's Juniors Body Enhancing Denim Shorts", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Denim'], 'features': ['Mid\xa0-rise distressed denim shorts with a cuffed hem and a "push up" fit for a curvier look. Traditional 5 pockets and zip fly closure construction.', 'Machine Wash Cold', '82% Cotton 16%Polyester 2% Spandex - super comfy stretch for a "push up" look', '12"/30 cm Top to Bottom 2.25"/6 cm Inseam - Measured on a Size Small (Model is 5\'5 and Wearing a Size S)', 'Size Info: Small - 1, 3 / Medium - 5, 7 / Large - 9, 11'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/71sbZlu0QBL._UY679_.jpg'}
# 34th
# {'id': 'B01H3D9AA2', 'title': "chouyatou Women's Perfectly Fit 5-Pockets Ripped Denim Jean Shorts", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Denim'], 'features': ['100% cotton', 'Imported', 'Machine Wash', 'Fabric: 100%cotton', 'Mid-waist with belt loops, regular fit', 'Classic five-pockets, destroyed holes, zipper fly with top button', 'Light wash and distressed cotton denim fabric, suitable for casual daily wear', 'Made in China and Shipped from China, free shipping need 7-14 days arrived'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/61Xh6AbTvVL._UX679_.jpg'}
# 35th
# {'id': 'B0131JMSCE', 'title': "Chic Classic Collection Women's Relaxed Fit Flat Bermuda Short", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Casual'], 'features': ['Dark Shade, Black Stretch: 80% Cotton, 19% Polyester, 1% Spandex; Mid Shade: 79% Cotton, 20% Cotton, 1% Spandex', 'Imported', 'Machine Wash', 'Stretch denim', 'Comfortable flat elastic waist', 'Slash front pocket', 'Lerner leg opening', '10 inch'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/81f5U8zDMWL._UX522_.jpg'}
# 36th
# {'id': 'B07L2LTWD3', 'title': "Tribear Women's Summer Ripped Hole High Waist Casual Short Jeans", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts'], 'features': ['Size: US 4 6 8 10 12 14 16', 'Material: 98% Cotton/2% Spandex,Denim Cotton Blend', 'High Waist,Hole,Ripped,Sexy,Washed,Solid, Active, Brief,with stretchy,Style Casual,Destroyed,denim shorts are summer favorite by Ladies.', 'Zip fly with button closure,It is cool and fashionable to wear such a destroyed shorts,Top off your ordinary casual when you match it with your simple attire.', 'These denim Distressed jeans pants are comfortable and amazingly versatile ,also comes with knee length perfectly showing your beautiful leg silhouette,perfectly shapes your curves.'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/61VGjKVTkuL._UX425_.jpg'}
# 37th
# {'id': 'B01FY9XE5O', 'title': 'HyBrid & Company Womens 11.5 inch Inseam Butt Lift Stretch Bermuda Shorts', 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Casual'], 'features': ['FABRIC: 76% COTTON | 22% POLYESTER | 2% SPANDEX', 'GREAT FOR ALL OCCASION: Perfect for picnic dates and backyard beers, these Bermuda shorts are the friends your backside has always needed. Its sexy reshaping is paired with a super-comfy stretch fit.', 'BUTT LIFTING: Enhance those curves with these Bermuda Short that do wonders for your body as well as your outfit. Forget padding or permanent surgery — these pants will amp up your assets effortlessly.', 'FIGURE SLIMMING: These short will instantly slim you. All those unwanted fat will be no where to be seen.', 'EASY CARE: Simply toss this pant into the washing machine and dryer for easy hassel free cleaning.', 'STRETCH AND COMFORT: Unlike any other bermuda our short are made with a premium cotton and spandex blended fabric, which offers stretch and comfort to you. Wearing this is like wearing a pair of yoga short.'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/71w2CgHRkBL._UY679_.jpg'}
# 38th
# {'id': 'B00KGN6EGK', 'title': "Rekucci Women's Ease in to Comfort Fit Pull-On Modern City Shorts", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Casual'], 'features': ['Made In Canada or Cambodia Easy Care Machine Wash', 'COMFORT FIT: Wide Smoothing Contour Waistband. Pull-on Styling. Added back darts for a perfect fit, no gaping!', 'CHIC DETAILS: Front and back pressed crease looks classic and chic. Faux Front Pockets.', 'VERSATILE: Longer Inseam of 12". Great for office and work outfits, or dress down for casual looks. Model is 5\'9" and wearing size 6.', 'Our Classic Stretch Woven Fabric: Solid Colors: 74% Rayon 22% Nylon 4% Spandex Melange Colors: 48% Polyester 27% Rayon 21%Nylon 4% Spandex'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/61axIintZXL._UY741_.jpg'}
# 39th
# {'id': 'B07J1RPGHR', 'title': "Amazon Brand - Daily Ritual Women's Linen Pull-on Short", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts'], 'features': ['100% Linen', 'Imported', 'Machine Wash', 'Made from 100% linen, these light and breathable shorts are a warm-weather staple', 'Clean lines and a relaxed fit highlight this knit culotte with an elastic waistband at the back and off-seam side pockets', 'Inseam: 4”', "Start every outfit with Daily Ritual's range of elevated basics", 'Model is 5\'11" and wearing a size 2'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/71zR--IKH3L._UX522_.jpg'}
# 40th
# {'id': 'B07PGDMJRG', 'title': "BLENCOT Women's Drawstring Elastic Waist Casual Solid Comfy Cotton Linen Beach Shorts", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts'], 'features': ['Polyester + Spandex', 'Imported', 'Drawstring closure', 'This Womens Shorts fabric is Soft, comfortable, healthy and breathable', 'Feature:Mid/High-rise elastic waistband for stretchy fit, side pockets, Basic Solid, Adjustable waist drawstring', 'This Shorts Suit for casual, party, beach, club, daily and summer wear', 'Soft machine wash or hand wash', 'Package Content:1 x Women Shorts'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/71gRwSYfruL._UY606_.jpg'}
# 41th
# {'id': 'B07CNG66KV', 'title': "The North Face Women's Aphrodite 2.0 Shorts", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Active', '›', 'Active Shorts'], 'features': ['Nylon,Spandex', 'Made in USA or Imported', 'The North Face Size Chart'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/61aupY5BAqL._UX425_.jpg'}
# 42th
# {'id': 'B013WBF9W2', 'title': "LEE Women's Relaxed Fit Avey Knit Waist Bermuda Short", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Casual'], 'features': ['100% Fabric content varies by color. Please see Product Description field for more details.', 'Imported', 'Machine Wash', "CONFIDENT STYLE: When you're wearing shorts, you want to feel relaxed and confident. The Avey Cargo Bermuda is the perfect blend of fineline twill stretch fabric, a knit waistband that moves with you, fun details and needle work and a casual, relaxed fit.", "STYLISH DESIGNS: Lee's full line of women's shorts, women's jeans, women's skirts, women's jackets & more provide you with a stylish wardrobe all year round. From denim skirts for summer barbecues to jean jackets for windy fall days, Lee keeps you going.", "MORE THAN DENIM: You already trust Lee to bring you your favorite jeans, but we're so much more than that! Lee makes quality, stylish jeans, khakis, dresses, skirts, jackets, belts, shorts, shirts, uniforms and more! Fill your closet with Lee quality.", "QUALITY OVER QUANTITY: For over 100 years, Lee has been making quality, dependable denim. We'd rather sell one quality garment than 100 inferior ones. If you're looking for quality jeans, shorts, jackets, skirts, overalls, belts or uniforms, look to Lee."], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/81OON1GtjtL._UX342_.jpg'}
# 43th
# {'id': 'B07TZ3VV5J', 'title': 'Womens Cover Up Pants Sexy Hollow Out Crochet High Waist Mesh Beach Bikini Swimsuits Pants', 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Swimsuits & Cover Ups', '›', 'Cover-Ups'], 'features': ['Material: this hollow out bathing suit pants made of high quality acrylic blended, soft, comfortable and durable', 'Style: Stylish Crochet Hollow Out Beachwear Bikini Swimsuit Cover up Pants', 'Features: Summer knitted beach cover ups, solid handmade crocheted sheer hollow out cover up pants, high waist tummy control swimsuit bikini pants', 'Unique Design: This solid crochet bathing suit cover up is featuring with drawstring adjustable around the waist, knitted hollow out design', 'Occasion: this crochet pants perfect for wearing at tanning salon, swimming pool, poolside, party, club, cocktail, casual, holiday, beach and summer wear', 'Guaranteed quality with hassle free return or exchange, you are backed by 30 day replacement and money back guarantee,either you love the product or you are entitled to a 100% refund'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/71IT%2BAkDKPL._UY879_.jpg'}
# 44th
# {'id': 'B07T5DXQ64', 'title': "Women's Casual Elastic Waist Summer Shorts Jersey Loose Walking Shorts Bathing Suits Bikinis", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Casual'], 'features': ['Material: this Bikini Board Shorts made of high quality acrylic blended, soft, comfortable and durable', 'Style：womens summer comfy casual swim cover up shorts high waist beach pants', 'Features: Summer knitted beach cover ups, solid handmade crocheted sheer hollow out cover up pants, high waist tummy control swimsuit bikini pants', 'Unique Design: This black bathing suits cover up shorts is featuring with drawstring adjustable around the waist, knitted hollow out design, flowy wide leg pants', 'Occasion: this solid color pants perfect for wearing at tanning salon, swimming pool, poolside, party, club, cocktail, casual, holiday, beach and summer wear'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/610qh7rhJrL._UY550_.jpg'}
# 45th
# {'id': 'B01L0MJ0JI', 'title': 'Women Butt Lift 3 Button High Wide Waist Stretch Denim Skinny Jeans Capri Bermuda Short', 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Jeans'], 'features': ['FABRIC: 65% COTTON | 32% POLYESTER | 3% SPANDEX', "MAXIMIZE YOUR SEXINESS: These pants do more than highlight your appealing areas, they maximize their impact. Wear them day or night and don't worry about giving anyone whiplash — that's why you're wearing them.", 'ALL DAY COMFORT: Zipper Fly, Belt Loop. The most comfortable Stretchy wide-waist that moves with you, providing all around ease & roominess, never too tight or restrictive', 'EASY CARE: Machine wash, Tumble dry', 'BUTT LIFTING: Lift that derriere into the air with these butt-boosting skinny jeans — no pads needed. The construction lifts and smooths, giving your rear assets all they need for an amped-up style that screams sex appeal from every agle.', 'ALL SEASON WEARING: Comes with different inseam, Pants, Capri and Bermuda,'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/61fdDhgCxpL._UY741_.jpg'}
# 46th
# {'id': 'B07K92XRNX', 'title': "LEE Women's Flex-to-go Relaxed Fit Pull-on Cargo Bermuda Short", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Casual'], 'features': ['98% Cotton, 2% Spandex', 'Imported', 'Pull On closure', 'Machine Wash', 'Mid rise, relaxed fit, Pull on short', 'Featuring a flex-comfort waistband; faux drawstring', 'Total of 6 pockets including side cargo pockets'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/714A0lU1-gL._UX342_.jpg'}
# 47th
# {'id': 'B077QTHLTS', 'title': "Romwe Women's Casual Elastic Waist Summer Shorts Jersey Walking Shorts", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Casual'], 'features': ['Attention: GO DOWN 1 OR 2 SIZE, runs large, the black/burgundy/green/sky blue/Yellow 2#/navy', 'Fabric: very stretchy and breathable fabric.', 'Frill waist, waist with elastic and adjustable self tie belt to fit you well, the thigh is loose.', 'Casual summer shorts, suitable for beach wear/sports workout/Walking/daily wear/vacation.', 'Refer our size chart(Not Amazon)/ XS-Waist: 24.4-45.7", Hip: 52.4", Length: 13.4", Thigh: 32.5"./ S-Waist: 26.0-47.2", Hip: 53.9", Length: 13.8", Thigh: 33.3"./ M-Waist: 27.6-48.8", Hip: 55.5", Length: 14.2", Thigh: 34.1"./ L-Waist: 29.1-50.4", Hip: 57.1", Length: 14.6", Thigh: 34.8"./'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/61l4Tdnv2bL._UX522_.jpg'}
# 48th
# {'id': 'B07MLRHBLS', 'title': "luvamia Women's Casual Mid Waisted Washed Frayed Pockets Denim Jean Short Skirt", 'category': ['Clothing, Shoes & Jewelry', '›', 'Novelty & More', '›', 'Clothing', '›', 'Novelty', '›', 'Women', '›', 'Skirts'], 'features': ['Imported', "Women's chic denim skirt with mid rise, washed design and whiskering details. Soft stretchable material.", 'Basic five pockets and button-and-zipper closure. Short jean skirt features stylish fringed hem for sweet girly vibes.', 'Slim fit. Above knee length. Color may be slight different due to the craft of washing.', 'Perfect for casual wear, going out, street fashion, dating, travel, holiday, summer and so on.', 'Size Small (fits US 4-US 6) fits Waist 25"-27", Hips 35.5"-37.5"; Size Medium (fits US 8-US 10) fits Waist 27"-29", Hips 37.5"-39.5"; Size Large (fits US 12-US 14) fits Waist 30"-32", Hips 40.5"-42.5"; Size X-Large (fits US 16-US 18) fits Waist 33"-35", Hips 43.5"-45.5", Size XX-Large (fits US 20-US 22) fits Waist 36"-39", Hips 46.5"-48.5".'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/71-fpNIU2OL._UX522_.jpg'}
# 50
# 2
# 49th
# {'id': 'B07DDD64VG', 'title': "Vcansion Women's Casual Shorts Knee-Length Bermuda Shorts Elastic Waist and Drawstring Closure", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Casual'], 'features': ['Fabric: Cotton 47%+Polyester 43%+Elastic spandex 10%；(A# Cotton and Spandex Blended).', 'Imported', 'Elastic waistband+Adjustable drawstring closure', '2 Slant Pocket,Lightweight comfortable and breathable', 'Designed with a mid/high rise and wide ribbed elastic drawstring waist, to cinch according to your needs.', 'Ideal for various occasions or everyday use.Slim fit,Comfortable', 'Soft machine wash or hand wash', 'ATTENTION:all items are US SIZE for selection.But few items tag shows the Asian Standard and old logo'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/61f2oedwpDL._UX342_.jpg'}
# 50th
# {'id': 'B079L4KHFC', 'title': "Milumia Women's Casual High Waisted Hemming Denim Jean Shorts Pockets", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts'], 'features': ['Material: Denim', 'Closure Type: Button Fly, Elastic Waist', 'Two pockets front and two pockets back, Classic blue denim shorts, casual design, perfect for beach, streetwear, casual out, holidays, travels, etc', 'Fashion hemming design,hem can be rolled up by yourself', 'XS -- US( 0 ), S -- US( 2 ), M -- US( 6 ), L -- US( 8 ), XL -- US( 10 ), XXL -- US( 12 ), XXXL -- US( 14 ), Please refer to the size measurement below before ordering'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/810YIm6L0eL._UY606_.jpg'}
# 51th
# {'id': 'B07P8QKH2S', 'title': "LookbookStore Women's Mid Rise Frayed Ripped Raw Hem Denim Jean Shorts", 'category': [], 'features': ['Imported', 'Casual summer high waist denim hot pants features washed distressed destroyed design and cute raw hemline', 'Slight side slit,5 pockets for practical use, zip fly and button closure', 'Soft, stretchy and comfortable, true to size, machine washable', 'Perfect for daily wear, street, going out, date, night out, party, club, or work, travel, etc', 'This item runs big. Before you choose your size, please check the specific measurement detail in the product description as reference'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/81cfNodOAgL._UX342_.jpg'}
# 52th
# {'id': 'B01EVYAPN2', 'title': 'HyBrid & Company Womens 3 inch Reg/5 inch Plus Inseam Butt Lifting Stretch Twill/Denim Shorts', 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts'], 'features': ['FABRIC: 76% COTTON | 22% POLYESTER | 2% SPANDEX', "SEXY SUMMER SHORT: Accentuate those curves with these dramatic shorts that lift your butt beautifully. Offering the stretch of twill and the sex appeal of summer, they're ready for wearing on warm days ahead.", 'STRETCH AND COMFORT: Unlike any other short our pant are made with a premium cotton and spandex blended fabric, which offers stretch and comfort to you. Wearing this is like wearing a pair of yoga pant.', 'EASY CARE: Machine washable, Tumble dry', 'BUTT LIFTING: Lift that derriere into the air with these butt-boosting skinny jeans — no pads needed. The construction lifts and smooths, giving your rear assets all they need for an amped-up style that screams sex appeal from every angle.', 'BRAND: Fame Fashion House is the only authorized seller of HyBrid & Company product. Do not buy from any other sellers as their product are counterfeit & not held to the high standard that we produce. We ship from USA'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/71EDIcoxw1L._UY741_.jpg'}
# 53th
# ...
# 573th
# {'id': 'B07GRK891H', 'title': "Roxy Women's Compass Direction Short Overalls", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts'], 'features': ['55% Linen, 45% Viscose', 'Imported', 'Adjustable closure', 'Machine Wash', 'Fit: regular', 'Fabric: linen viscose', '2 patch pockets at front'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/71lQLwMp7%2BL._UX466_.jpg'}
# 574th
# {'id': 'B07BK4GJKY', 'title': 'Barefoot Dreams CozyChic Ultra Lite Shorts', 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts'], 'features': ['BE AT EASE IN THIS VERSATILE Barefoot Dreams Ultra Lite Shorts, with an elasticized waist with adjustable drawstring and rolled hem', 'ENJOY SUMMERS IN STYLE with your new Barefoot Dreams Ultra Lite Shorts. Perfect for all day lounging and on the go', 'STAY COOL AND STYLISH while you stroll down the beach, a walk in the park or on the plane, as they are the perfect travel companion', 'DELICATE OPEN STITCH HEM adds extra comfort and ensure a better fit', 'FABRIC: 71% nylon, 29% viscose'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/71oWRqb4cuL._UY606_.jpg'}
# 575th
# {'id': 'B07BCS5X2G', 'title': 'J. Crew Women\'s 9" Chino Shorts in Multiple Colors and Sizes', 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Casual'], 'features': ['Cotton and Elastane blend with a hint of stretch for extra comfort. Machine Washable.', '9" inseam with a classic zip fly. Great tailored length and wider waistband.', 'Front pockets set off-seam and 2 back welt pockets.', 'Sit just above the hip for all day comfort.', 'The perfect shorts for all day wear with added comfort and coverage due to the longer inseam. Easily cuffed if a shorter look is your preference.'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/71FqUjbOHnL._UX569_.jpg'}
# 576th
# {'id': 'B073BTD2LD', 'title': "Ruby Rd. Women's Fly Front Super Stretch Solar Millennium Tech Short", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts'], 'features': ['78% Rayon, 19% Nylon, 3% Spandex', 'Imported', 'Button Fly closure', 'Machine Wash', 'Fly front', 'Side hem slits', 'Belt loops', 'Front slash pockets'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/71DX9gw7ecL._UX522_.jpg'}
# 50
# 2
# 577th
# {'id': 'B06X19BW3P', 'title': "[BLANKNYC] Women's Cuffed Distressed Short", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts'], 'features': ['97% Cotton, 2% Polyester, 1% Spandex', 'Imported', 'Machine Wash', 'The front rise is 8 3/4 inches', 'The inseam with rolled cuff is 3 inches'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/81WENrxBMuL._UX342_.jpg'}
# 578th
# {'id': 'B01FS4GX30', 'title': 'Celebrity Pink Jeans Women\'s Celebrity Pink Color 3" Mid Rise Cuffed Short', 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts'], 'features': ['57% Cotton, 41% Rayon, 2% Spandex', 'Imported', 'Machine Wash', 'Mid rise-waistband sits just below natural waist', '3 inch inseam'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/71Jwu9c3e0L._UX466_.jpg'}
# 579th
# {'id': 'B072YK9CMY', 'title': "Billabong Women's Lite Hearted Denim Short", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Denim'], 'features': ['98% Cotton, 2% Elastane', 'Imported', 'Tie closure', 'Machine Wash', 'Five Pocket Denim Cut Off Short', 'Lace-Up Front'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/81bB22R2HmL._UY500_.jpg'}
# 580th
# {'id': 'B07QKG7BMJ', 'title': "SHOP DORDOR Women's Casual Summer Pockets Soft Harem Shorts", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts'], 'features': ['96% Polyester / 4% Spandex', 'Casual Summer Soft Harem Shorts with Pockets and Wide Waistband', 'Features: Side Pockets, Banded Waist, Soft, Stretchy, and Comfortable Fabric', 'Occasion: Casual, Beach, Daily, Home, Date, Vacation, Yoga, Exercise, Activity', 'Please check our size chart in the image for the most accurate fit.', 'US SIZE:S=(US 4-6),M=(US 8-10),L=(US 12-14),XL=(US 16-18).Model\'s Measurement: Height: 5\'10"/178cm Bust: 34"/86cm Waist: 25"/63.5cm Hip: 35"/89cm Wearing a size Small'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/51N0vNK6MqL._UY606_.jpg'}
# 581th
# {'id': 'B01B00CYUM', 'title': "Bellarize Women's Crochet Lace Shorts with Inner Lining", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Casual'], 'features': ['Elastic Waistline', 'Soft inner lining for all-day comfort and style', 'Recommended Care Instructions: Hand Wash Cold. Do Not Bleach. Hang Dry.', 'Imported'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/61RVgWb49XL._UY879_.jpg'}
# 582th
# {'id': 'B075VNFNFX', 'title': "Vintage America Blues Women's Boho Roll Cuff Bermuda Short", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts'], 'features': ['79% Cotton, 20% Polyester, 1% Elastane', 'Imported', 'Zipper closure', 'Machine Wash', 'Roll cuff hem', 'Good stretch for a comfortable fit'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/81lm4P5GUSL._UX342_.jpg'}
# 583th
# {'id': 'B07MZBNK76', 'title': 'J.Crew Mercantile Women\'s 10" Cutoff Garment Dyedd Denim Boy Short', 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Denim'], 'features': ['99% Cotton, 1% Elastane', 'Imported', 'Zipper closure', 'Machine Wash', '3" Inseam', 'Sits above hip. Zip fly with button-tab closure', 'Available matching separates to complete the look', "J. Crew mercantile's versatile staples, perfected over decades. Timeless Classics, everyday necessities, and statement pieces that become your go-tos."], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/712zzrLKpQL._UX466_.jpg'}
# 584th
# {'id': 'B07MZRBYXZ', 'title': "AG Adriano Goldschmied Women's Hailey Cut-Off Short", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Contemporary & Designer', '›', 'Clothing', '›', 'Shorts', '›', 'Denim'], 'features': ['98% Cotton, 2% Polyurethane', 'Imported', 'Button closure', 'Machine Wash', '10 oz. Dover Stretch denim', 'Classic five-pocket design. Finished with a zip-fly and button closure.', 'Rise: 10"'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/71Knl8m4XDL._UY550_.jpg'}
# 585th
# {'id': 'B07T26TT71', 'title': "HUE Women's Ultra Soft Denim High Waist Shorts", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts'], 'features': ['60% Cotton, 37% Polyester, 3% Spandex', 'Imported', 'Pull On closure', 'Machine Wash', 'Ultra Soft Denim shorts look and feel like your favorite pair of cut-off jeans, with extra softness and stretch for a comfortable fit all day long', 'Trendy design features a frayed hem, goldtone hardware, and contrast stitching', 'Designed to accentuate your natural curves, these shorts are ready to party when the sun comes out'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/81L65s7NpsL._UX466_.jpg'}
# 586th
# {'id': 'B07L7RW2JR', 'title': 'Blank NYC Womens The Lenox Distressed Shorts in Great White', 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Denim'], 'features': ['88% cotton, 9% polyester, 3% spandex', 'Imported', 'Zipper closure', '[BLANKNYC] Size Chart'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/61vUY9REBFL._UY445_.jpg'}
# 587th
# {'id': 'B07CSHF74F', 'title': "Zenana ZONE12SPORTS Women's Premium Cotton Biker Shorts", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts'], 'features': ['Cotton Biker Shorts', '95% Cotton, 5% Spandex', 'Color may vary slightly due to monitor resolution'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/61uBpiKizvL._UY500_.jpg'}
# 588th
# {'id': 'B07RTXJZMR', 'title': "Floerns Women's Plus Size Shorts Summer Floral Tie Waist Shorts with Pockets", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts'], 'features': ['Fabric: material has no stretch, waist is stretchy, lightweight and comfortable', 'Features: boho style, floral print, elastic waist, tie waist, loose fit, pockets', 'Occations: beach/ vacation/ cruise/ pool/ concert/ causal wear etc, perfect for summer', 'Garment Care: Hand or gentle machine wash in cold water. Do Not bleach', 'Please refer to Size Chart in Product Description or last picture as below'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/71n7lGQZjrL._UY741_.jpg'}
# 589th
# {'id': 'B07C7PRTGP', 'title': "HARBETH Women's Juniors Casual Stretch Fit Low Rise Pockets Trendy Denim Shorts", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Denim'], 'features': ['82%Cotton 15%Poly 3%Spandex Medium Weight High End Quality Stretch Denim.', 'US Miss/Junior Standard Fit, Sit Naturally On Waist, 3" Inseam.', 'Clean Cut Basic Denim Shorts Featuring Cuffed Leg.', 'A Versatile Basic Denim Shorts For Work And Weekend.', 'Internal Quality Control Processed To Ensure Quality, Fit And Comfort.', 'In Compliance With Amazon Free Return Policy.'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/81SZ5NwNBJL._UX569_.jpg'}
# 590th
# {'id': 'B07895MCHX', 'title': "Wrangler Women's Aura Instantly Slimming Mid Rise Stretch Jean Short", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Denim'], 'features': ['94% Cotton, 5% Polyester, 1% Spandex', 'Imported', 'Zipper closure', 'Machine Wash', 'Contour waist', 'Five pocket styling', 'Hip pocket embroidery'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/815lgAoa3tL._UX466_.jpg'}
# 591th
# {'id': 'B074J9KPX8', 'title': "LEE Women's Plus-Size Relaxed Fit Diani Knit Waist Bermuda Short", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Casual'], 'features': ['Black, Tarmac, Blue Horizon, Bungalow Khaki: 98% Cotton, 2% Spandex; Twilight: 75% Cotton, 23% Polyester, 2% Spandex', 'Imported', 'Zipper closure', 'Machine Wash', 'Relaxed fit with a knit waistband', 'Utility-style Bermuda short featuring front slanted patch pockets and button closure', 'Functional side cargo flap pockets'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/71VE-dwsgRL._UY879_.jpg'}
# 592th
# {'id': 'B00MPBFWN2', 'title': 'Dickies Juniors Stretch Bermuda Short', 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Casual'], 'features': ['98% Cotton/2% Spandex', 'Imported', 'Machine Wash', 'Solid bermuda short in classic stretch fit featuring welted back pockets', 'Inseam: 13"'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/71D%2BDAQcQpL._UY550_.jpg'}
# 593th
# {'id': 'B07SPYSTFJ', 'title': "Utyful Women's Mid Waist Ripped Raw Cut Hem Washed Distressed Denim Jean Shorts", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts'], 'features': ['Imported', '5-pocket shorts in washed denim with distressed details. Regular waist, zip fly, and raw-edge hems.', 'This pair of jeans shorts featuring distressed details at front create a cool style, its cut from substantial fabric for a comfortable fit.', 'Pair perfectly with all kinds of tops, flats and boots. Suitable for casual, daily life, shopping, party and many occasions.', 'Wash and dry inside out with similar colors. Liquid detergent is recommended.', 'Size S(US 4-6): Waist 25" - 27" / Hips 35.5" - 37.5"; Size M(US 8-10): Waist 27" - 29" / Hips 37.5" - 39.5"; Size L(US 12-14): Waist 30" - 32" / Hips 40.5" - 42.5"; Size XL(US 16-18): Waist 33" - 35" / Hips 43.5" - 45.5"; Size XXL(US 20-22): Waist 36" - 39" / Hips 46.5" - 48.5".'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/81IxM4FpQrL._UY550_.jpg'}
# 594th
# {'id': 'B07GXWQB31', 'title': "Wrangler Women's Retro Mae Mid Rise Stretch Jean Short", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts', '›', 'Denim'], 'features': ['76% Cotton, 23% Polyester, 1% Spandex', 'Imported', 'Zipper closure', 'Machine Wash', 'Mid Rise', 'Contour Waist', '"W" Embroidery on Hip Pockets'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/8191RcI7X-L._UX342_.jpg'}
# 595th
# {'id': 'B077N5FDYP', 'title': "Rela Bota Women's Casual Soft High Waist Velvet Drawstring Casual Booty Shorts", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts'], 'features': ['Material: Velvet&Polyester', 'Fabric: Made of Velvet, Soft and cozy feeling', 'Features: high waisted with adjustable tie belt around, fitted type and stretchy material.', 'Suitable for: club,night out, party, casual wear, leisure time with basic shirt, or sports activities, like yoga or running, can also wear it as a sleeping pants if you want', 'A good all-match to pair them with crop top,leggings,sweaters,blouse,tunics,jacket or long coat', '1-2 business days for FBA delivery / 7-15 business days for Non-FBA delivery'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/61qHRntO5qL._UX679_.jpg'}
# 596th
# {'id': 'B07K23PG2L', 'title': "[BLANKNYC] Women's The Essex Shorts", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts'], 'features': ['88% Cotton, 9% Polyester, 3% Spandex', 'Imported', 'Zipper closure', 'Machine Wash', 'Stretch fabric', 'Zip fly'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/81hPsVG7SnL._UY879_.jpg'}
# 597th
# {'id': 'B07S7MDZZ5', 'title': "Gloria Vanderbilt Women's Lillian Belted Skimmer Capri", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts'], 'features': [], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/61XlK64vYqL._UY679_.jpg'}
# 598th
# {'id': 'B07C342MSG', 'title': "WallFlower Women's Juniors Soft Cuffed Hem Ultra Shorts", 'category': ['Clothing, Shoes & Jewelry', '›', 'Women', '›', 'Clothing', '›', 'Shorts'], 'features': ['Imported', 'Machine washable cold and tumble dry low', 'Zipper fly and double button closure', 'Very soft and comfortable, wear anytime!', '3" cuffed inseam', 'Mid-rise, sits low on hip'], 'gender': 'woman', 'img_links': 'https://images-na.ssl-images-amazon.com/images/I/619Ga4kxdgL._UY606_.jpg'}
# 0
# -48

# %%
print(len(a_list))
# Out:
# 26
