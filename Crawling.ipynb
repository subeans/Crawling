# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import urllib.request as ur
import random
import time
import json

# %%
crawling_id = 'merge_no_image_t.json'

# %%
with open(crawling_id) as d:
    dataids = json.load(d)

# %%
def getFeature(id_list, bad_list, good_list):
    options = webdriver.ChromeOptions()
    driver = webdriver.Chrome('./chromedriver')
    driver.implicitly_wait(1)
    driver.get('https://www.amazon.com/ref=nav_logo?language=en_US')
    
    for i in range(len(dataids)):
    #for i in range(34443,44443):
        id = id_list[i]
        gender = 'male'
        info = {}
        url = 'https://www.amazon.com/dp/' + id
        print(url)
        try:
            driver.get(url)
            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')

            title = soup.select('#productTitle')[0].text.strip()

           # category_select = soup.select('#wayfinding-breadcrumbs_feature_div > ul > li > span')
            #category = []
            #for single_category in category_select:
            #   category.append(single_category.text.strip())

            #feature_select = soup.select('#feature-bullets > ul > li > span')
            #feature = []
            #for single_feature in feature_select:
            #    feature.append(single_feature.text.strip())

            imgurl_select = soup.select('#landingImage')[0]['data-a-dynamic-image']
            imgurl = (imgurl_select.split('\"')[1])

            info = {
                'id' : id,
                #'title' : title,
                #'category' : category,
                #'features' : feature,
                #'gender' : gender,
                'img_links' : imgurl
            }
            if i % 50 == 0:
                print(str(i) + ' th crawling data')
                print(info)
            
            good_list.append(info)
            
        except:
            bad_list.append(id)

# %%
test = dataids
len(test)
# Out:
# 102278

# %%
bad_list = []
good_list = []
getFeature(test, bad_list, good_list)
json.dump(good_list, open('./img_link_reselect2.json', 'w+'))
json.dump(bad_list,open('./no_img_link_bad.json','w+'))
# Out:
# https://www.amazon.com/dp/B07CN7DKN8
# https://www.amazon.com/dp/B07HFL76B2
# https://www.amazon.com/dp/B07KDVHDK4
# https://www.amazon.com/dp/B077S8XRD5
# https://www.amazon.com/dp/B06XTNWZ61
# https://www.amazon.com/dp/B07KCDGVM1
# https://www.amazon.com/dp/B07KG2S36Y
# https://www.amazon.com/dp/B07BNBLV7G
# https://www.amazon.com/dp/B07K9ZFTRY
# https://www.amazon.com/dp/B07HMRNK3D
# https://www.amazon.com/dp/B06ZZ75255
# https://www.amazon.com/dp/B07HFLD7VK
# https://www.amazon.com/dp/B07DLM7CX7
# https://www.amazon.com/dp/B07L4SNGRG
# https://www.amazon.com/dp/B00ZFMML78
# https://www.amazon.com/dp/B07HFKSVLP
# https://www.amazon.com/dp/B01FRUQCX6
# https://www.amazon.com/dp/B076XF63Z3
# https://www.amazon.com/dp/B07GTQMB86
# https://www.amazon.com/dp/B07HFKRRJJ
# https://www.amazon.com/dp/B07HFPZHXR
# https://www.amazon.com/dp/B07J419RXL
# https://www.amazon.com/dp/B07L8WYZX4
# https://www.amazon.com/dp/B072KF4W9F
# https://www.amazon.com/dp/B07HFLQZKJ
# https://www.amazon.com/dp/B07K6GR3MK
# https://www.amazon.com/dp/B07HFK88XM
# https://www.amazon.com/dp/B077PGN48C
# https://www.amazon.com/dp/B07HFKFD4C
# https://www.amazon.com/dp/B07KT1NS8X
# https://www.amazon.com/dp/B07K1QSQCL
# https://www.amazon.com/dp/B079THKD8K
# https://www.amazon.com/dp/B07KT2RF51
# https://www.amazon.com/dp/B07JQ2QL32
# https://www.amazon.com/dp/B07KXHG5JV
# https://www.amazon.com/dp/B07FMR57GC
# https://www.amazon.com/dp/B07HFK852Z
# https://www.amazon.com/dp/B07HFKHJN4
# https://www.amazon.com/dp/B07HFKJL6F
